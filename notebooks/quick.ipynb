# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/Users/brianthuynh/dev/dsc180-capstone/bnpp-reports-clean.csv', nrows=100, usecols=['Phonetic', 'ReportClean'])

# %%
df.to_csv('/Users/brianthuynh/dev/dsc180-capstone/models/mediphi/sample_data.csv', index=False)
